# %% [markdown]
# #Read Silver Tables

# %%
# %sql

SELECT *
FROM health.silver.billing
LIMIT 10;

# %%
# %sql

SELECT *
FROM health.silver.admissions
LIMIT 10;

# %%
# %sql

SELECT *
FROM health.silver.hospitals
LIMIT 10;

# %% [markdown]
# #Data Integration

# %%
# %sql

SELECT
    b.admission_id,
    b.total_cost,
    h.state
FROM health.silver.billing b
INNER JOIN health.silver.admissions a
    ON b.admission_id = a.admission_id
INNER JOIN health.silver.hospitals h
    ON a.hospital_id = h.hospital_id;

# %% [markdown]
# #Business Aggregation

# %%
# %sql

SELECT
    h.state,
    SUM(b.total_cost) AS total_revenue
FROM health.silver.billing b
INNER JOIN health.silver.admissions a
    ON b.admission_id = a.admission_id
INNER JOIN health.silver.hospitals h
    ON a.hospital_id = h.hospital_id
GROUP BY
    h.state
ORDER BY
    total_revenue DESC;

# %% [markdown]
# #Create Gold Table

# %%
# %sql

CREATE OR REPLACE TABLE health.gold.revenue_by_state AS

SELECT
    h.state,
    SUM(b.total_cost) AS total_revenue
FROM health.silver.billing b
INNER JOIN health.silver.admissions a
    ON b.admission_id = a.admission_id
INNER JOIN health.silver.hospitals h
    ON a.hospital_id = h.hospital_id
GROUP BY
    h.state;

# %% [markdown]
# ###Gold Table Verification

# %%
# %sql

SELECT *
FROM health.gold.revenue_by_state
ORDER BY total_revenue DESC;
